# %%
# --
# title: "My app title 🚀"
# description: "Data app with many calculations"
# params:
#     variable:
#         input: "text"
#         label: "Please provide text"
# --
# Out:
#   Input In [4]
#     --
#       ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd

df = pd.read_csv ("testTable2.csv")
df.drop_duplicates(subset ="PLAYER",
                      inplace = True)




df['AVG'] = pd.to_numeric(df['AVG'], errors='coerce')
df = df.replace(np.nan, 0, regex=True)
#print(df)
#print(df.dtypes)

df.sort_values(by='AVG',ascending=False,inplace=True)




## Potential Points
potPoints=[]
potTeam=[]
## Relevante Spalten behalten
df=df[['PLAYER','TYPE','AVG']]

# Dataframe Filtern --> Top5 pro Team zum Testen
## Positionsspalte erstellen

df['Position']=""

df['Position']=df['PLAYER'].str[-2:]
df.loc[df['PLAYER'].str[-1:]=="K", 'Position'] = 'K'

### Filtern und Zählen
franchises=df['TYPE'].unique()

for t in franchises:
    teamlist=(df[df.TYPE == t])

    flex=pd.DataFrame()
    #Liste für jede Position erstellen RB,WR,TE,QB,FLEX,K,DEF und danach wo notwendig 2 (qb1) spieler zum Flex pool zuweisen
    #QB
    QB=teamlist[teamlist.Position == 'QB'].head(1)
    try:
        flex=pd.concat([flex, teamlist[teamlist.Position=='QB'].iloc[[1]]])
    except:
        pass
    ##RB
    RB=teamlist[teamlist.Position == 'RB'].head(2)
    try:
        flex=pd.concat([flex, teamlist[teamlist.Position=='RB'].iloc[2:]])
    except:
        pass
    ##WR
    WR=teamlist[teamlist.Position == 'WR'].head(3)
    try:
        flex=pd.concat([flex, teamlist[teamlist.Position=='WR'].iloc[3:]])
    except:
        pass
    ##TE
    TE=teamlist[teamlist.Position == 'TE'].head(1)
    try:
        flex=pd.concat([flex, teamlist[teamlist.Position=='TE'].iloc[1:]])
    except:
        pass
    ## K
    K=teamlist[teamlist.Position == 'K'].head(1)

    ## DEF
    ST=teamlist[teamlist.Position == 'ST'].head(1)

    ##Flex
    flex.sort_values(by='AVG',ascending=False)
    flex=flex.iloc[[0,1]]

    team=pd.concat([QB,RB,WR,TE,K,ST,flex])

    ## Punkte addieren
    teamsum=pd.to_numeric(team['AVG']).sum()
    ##raussschreiben
    potPoints.append(
        
            {  
                'Team': t,
                'Potential Points':  teamsum
            }
        )

    potTeam.append(
        
            {  
                'Team': t,
                'Potential Team':  team
            }
        )    

print(potPoints)
print(potTeam)



### Abspeichern
# Out:
# [{'Team': 'PP', 'Potential Points': 136.6}, {'Team': 'MHB', 'Potential Points': 135.5}, {'Team': 'LCow', 'Potential Points': 131.1}, {'Team': 'BIBO', 'Potential Points': 129.49999999999997}, {'Team': 'MLFS', 'Potential Points': 129.70000000000002}, {'Team': 'OTK', 'Potential Points': 131.70000000000002}, {'Team': 'DOM', 'Potential Points': 116.4}, {'Team': 'FLY', 'Potential Points': 138.0}, {'Team': 'CML', 'Potential Points': 127.20000000000002}, {'Team': 'REIC', 'Potential Points': 125.49999999999997}]
# [{'Team': 'PP', 'Potential Team':                     PLAYER TYPE   AVG Position
# 41       Josh Allen\nBufQB   PP  23.4       QB
# 40       Josh Jacobs\nLVRB   PP  13.0       RB
# 35   Antonio Gibson\nWshRB   PP  12.8       RB
# 24     Tee HigginsQ\nCinWR   PP  12.4       WR
# 25        DJ MooreQ\nCarWR   PP  12.0       WR
# 38    Jaylen Waddle\nMiaWR   PP  11.5       WR
# 19     Mark Andrews\nBalTE   PP  12.1       TE
# 188     Younghoe Koo\nAtlK   PP   7.4        K
# 183   Eagles D/ST\nPhiD/ST   PP   5.8       ST
# 205    Zach WilsonQ\nNYJQB   PP  15.8       QB
# 97     Tony Pollard\nDalRB   PP  10.4       RB}, {'Team': 'MHB', 'Potential Team':                         PLAYER TYPE   AVG Position
# 47       Patrick Mahomes\nKCQB  MHB  21.9       QB
# 27           Aaron Jones\nGBRB  MHB  15.1       RB
# 34          Breece Hall\nNYJRB  MHB  12.9       RB
# 36       Terry McLaurin\nWshWR  MHB  11.5       WR
# 42     Courtland Sutton\nDenWR  MHB  11.1       WR
# 123          Chris Olave\nNOWR  MHB   9.3       WR
# 49           Kyle Pitts\nAtlTE  MHB  10.0       TE
# 241              Wil Lutz\nNOK  MHB   7.4        K
# 179     Dolphins D/ST\nMiaD/ST  MHB   6.4       ST
# 160  Deshaun WatsonSSPD\nCleQB  MHB  18.7       QB
# 82   Travis Etienne Jr.\nJaxRB  MHB  11.2       RB}, {'Team': 'LCow', 'Potential Team':                       PLAYER  TYPE   AVG Position
# 145    Tua Tagovailoa\nMiaQB  LCow  16.9       QB
# 0     Jonathan Taylor\nIndRB  LCow  19.8       RB
# 21         Cam AkersQ\nLARRB  LCow  14.1       RB
# 12        CeeDee Lamb\nDalWR  LCow  13.3       WR
# 43   Diontae JohnsonQ\nPitWR  LCow  11.0       WR
# 87      DeVonta Smith\nPhiWR  LCow  10.1       WR
# 298       O.J. Howard\nBufTE  LCow   2.8       TE
# 169       Jake Elliott\nPhiK  LCow   7.8        K
# 121    Cowboys D/ST\nDalD/ST  LCow   6.4       ST
# 245    Marcus Mariota\nAtlQB  LCow  15.6       QB
# 39    Ezekiel Elliott\nDalRB  LCow  13.3       RB}, {'Team': 'BIBO', 'Potential Team':                          PLAYER  TYPE   AVG Position
# 153      Trevor Lawrence\nJaxQB  BIBO  16.2       QB
# 3    Christian McCaffrey\nCarRB  BIBO  18.9       RB
# 6          Austin Ekeler\nLACRB  BIBO  16.7       RB
# 44       Marquise BrownQ\nAriWR  BIBO  10.9       WR
# 117      Kadarius ToneyQ\nNYGWR  BIBO  10.1       WR
# 88    JuJu Smith-Schuster\nKCWR  BIBO  10.0       WR
# 133            Noah Fant\nSeaTE  BIBO   6.8       TE
# 208        Dustin Hopkins\nLACK  BIBO   7.6        K
# 171       Patriots D/ST\nNED/ST  BIBO   5.8       ST
# 174        Justin Fields\nChiQB  BIBO  15.8       QB
# 122   Rhamondre Stevenson\nNERB  BIBO  10.7       RB}, {'Team': 'MLFS', 'Potential Team':                     PLAYER  TYPE   AVG Position
# 136    Kirk Cousins\nMinQB  MLFS  16.8       QB
# 8       Dalvin Cook\nMinRB  MLFS  16.9       RB
# 13        Joe Mixon\nCinRB  MLFS  15.8       RB
# 10     Stefon Diggs\nBufWR  MLFS  13.2       WR
# 29     Keenan Allen\nLACWR  MLFS  12.8       WR
# 84     Chris GodwinQ\nTBWR  MLFS  11.0       WR
# 185     Evan Engram\nJaxTE  MLFS   6.6       TE
# 148   Browns D/ST\nCleD/ST  MLFS   6.2       ST
# 200    Carson Wentz\nWshQB  MLFS  15.9       QB
# 28   Saquon Barkley\nNYGRB  MLFS  14.5       RB}, {'Team': 'OTK', 'Potential Team':                        PLAYER TYPE   AVG Position
# 203       Daniel Jones\nNYGQB  OTK  16.9       QB
# 17       D'Andre Swift\nDetRB  OTK  15.0       RB
# 33   David MontgomeryQ\nChiRB  OTK  13.2       RB
# 5        Ja'Marr Chase\nCinWR  OTK  14.7       WR
# 9          Deebo Samuel\nSFWR  OTK  14.0       WR
# 74       Gabriel Davis\nBufWR  OTK  11.0       WR
# 150     Irv Smith Jr.Q\nMinTE  OTK   6.9       TE
# 201           Cade York\nCleK  OTK   7.2        K
# 108       Colts D/ST\nIndD/ST  OTK   6.5       ST
# 272     Desmond Ridder\nAtlQB  OTK  14.7       QB
# 79    Devin Singletary\nBufRB  OTK  11.6       RB}, {'Team': 'DOM', 'Potential Team':                      PLAYER TYPE   AVG Position
# 189         Mac Jones\nNEQB  DOM  14.8       QB
# 1      Derrick Henry\nTenRB  DOM  16.8       RB
# 14       Alvin Kamara\nNORB  DOM  16.4       RB
# 30     Mike Williams\nLACWR  DOM  12.0       WR
# 31        A.J. Brown\nPhiWR  DOM  11.6       WR
# 46       Jerry Jeudy\nDenWR  DOM  11.0       WR
# 110      Dawson Knox\nBufTE  DOM   7.5       TE
# 147  Chargers D/ST\nLACD/ST  DOM   6.1       ST
# 64    Miles SandersQ\nPhiRB  DOM  12.4       RB
# 184  Jamaal Williams\nDetRB  DOM   7.8       RB}, {'Team': 'FLY', 'Potential Team':                        PLAYER TYPE   AVG Position
# 115          Derek Carr\nLVQB  FLY  16.2       QB
# 20        James Conner\nAriRB  FLY  15.5       RB
# 15    Leonard Fournette\nTBRB  FLY  15.3       RB
# 2          Cooper Kupp\nLARWR  FLY  15.9       WR
# 11        Davante Adams\nLVWR  FLY  13.7       WR
# 93        Adam Thielen\nMinWR  FLY  10.5       WR
# 23         Travis Kelce\nKCTE  FLY  12.2       TE
# 128         Matt Prater\nAriK  FLY   7.9        K
# 139  Commanders D/ST\nWshD/ST  FLY   6.4       ST
# 280    Jacoby Brissett\nCleQB  FLY  13.8       QB
# 91         Kareem Hunt\nCleRB  FLY  10.6       RB}, {'Team': 'CML', 'Potential Team':                      PLAYER TYPE   AVG Position
# 187   Jameis WinstonQ\nNOQB  CML  16.0       QB
# 7       Najee Harris\nPitRB  CML  15.5       RB
# 22        Nick Chubb\nCleRB  CML  13.5       RB
# 16       Tyreek Hill\nMiaWR  CML  12.7       WR
# 26        Mike EvansQ\nTBWR  CML  11.6       WR
# 76    Darnell Mooney\nChiWR  CML  10.9       WR
# 113   Pat Freiermuth\nPitTE  CML   7.0       TE
# 181        Ryan Succop\nTBK  CML   7.6        K
# 142  Steelers D/ST\nPitD/ST  CML   6.4       ST
# 261       Drew LockQ\nSeaQB  CML  15.1       QB
# 85      Damien Harris\nNERB  CML  10.9       RB}, {'Team': 'REIC', 'Potential Team':                          PLAYER  TYPE   AVG Position
# 198       Ryan Tannehill\nTenQB  REIC  15.8       QB
# 18      Javonte Williams\nDenRB  REIC  14.2       RB
# 32         J.K. DobbinsQ\nBalRB  REIC  13.4       RB
# 4       Justin Jefferson\nMinWR  REIC  15.0       WR
# 100  DeAndre HopkinsSSPD\nAriWR  REIC  12.2       WR
# 37   Michael Pittman Jr.\nIndWR  REIC  11.6       WR
# 196        Robert TonyanQ\nGBTE  REIC   6.6       TE
# 172           Greg Joseph\nMinK  REIC   7.9        K
# 233       Vikings D/ST\nMinD/ST  REIC   5.1       ST
# 256          Davis Mills\nHouQB  REIC  14.1       QB
# 104             AJ Dillon\nGBRB  REIC   9.6       RB}]
